# %% [markdown]
# <a href="https://colab.research.google.com/github/Maryam-Zubair/Data-Science/blob/main/data_manipulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. REad `US_Baby_Names_right.csv` and Assign it to a variable called baby_names.

# %%
baby_names = pd.read_csv('US_Baby_Names_right.csv')

# %% [markdown]
# ### Step 3. See the first 10 entries

# %%
baby_names.head()
# Out:
#    Unnamed: 0     Id     Name  Year Gender State  Count
# 0       11349  11350     Emma  2004      F    AK     62
# 1       11350  11351  Madison  2004      F    AK     48
# 2       11351  11352   Hannah  2004      F    AK     46
# 3       11352  11353    Grace  2004      F    AK     44
# 4       11353  11354    Emily  2004      F    AK     41

# %% [markdown]
# ### Step 4. Delete the column 'Unnamed: 0' and 'Id'

# %%
baby_names.drop(['Unnamed: 0', 'Id'], axis=1, inplace=True)

# %% [markdown]
# ### Step 5. Are there more male or female names in the dataset?

# %%
baby_names.shape
# Out:
# (1016395, 7)

# %%
baby_names.drop_duplicates('Name').groupby('Gender').size()
# Out:
# Gender
# F    10393
# M     7239
# dtype: int64

# %% [markdown]
# ### Step 6. Group the dataset by name, count them

# %%
baby_names.groupby('Name')['Count'].sum()
# Out:
# Name
# Aaban        12
# Aadan        23
# Aadarsh       5
# Aaden      3426
# Aadhav        6
#            ...
# Zyra         42
# Zyrah        11
# Zyren         6
# Zyria        59
# Zyriah       58
# Name: Count, Length: 17632, dtype: int64

# %% [markdown]
# ### Step 7. How many different names exist in the dataset?

# %%
baby_names.drop_duplicates('Name').shape[0]
# Out:
# 17632

# %% [markdown]
# ### Step 8. What is the name with most occurrences?

# %%
baby_names.groupby('Name')['Count'].sum().sort_values(ascending=False) # giving us all names, we only need Jacob
# Out:
# Name
# Jacob         242874
# Emma          214852
# Michael       214405
# Ethan         209277
# Isabella      204798
#                ...
# Eniola             5
# Atlantis           5
# Marci              5
# Simarpreet         5
# Nita               5
# Name: Count, Length: 17632, dtype: int64

# %%
baby_names.groupby('Name')['Count'].sum().sort_values(ascending=False).index[0] # if name then go to index then pick 1st one as it has been repeated most of the times
# Out:
# 'Jacob'

# %%
baby_names['Name'].mode() #
# Out:
# 0    Riley
# Name: Name, dtype: object

# %% [markdown]
# ### Step 9 . How many different names have the least occurrences?

# %%
min = baby_names.groupby('Name')['Count'].sum().sort_values(ascending=True)[0]

# %%
Names_sorted = baby_names.groupby('Name')['Count'].sum().sort_values(ascending=True)
Names_sorted[Names_sorted==min].index.tolist()
# Out:
# ['Destenie',
#  'Janisha',
#  'Lizvet',
#  'Arsalan',
#  'Janira',
#  'Chuck',
#  'Sadrac',
#  'Theodoros',
#  'Sady',
#  'Janila',
#  'Arshiya',
#  'Llana',
#  'Sadye',
#  'Janiaya',
#  'Artavis',
#  'Lochlann',
#  'Minah',
#  'Min',
#  'Chukwuebuka',
#  'Christoph',
#  'Thi',
#  'Sadler',
#  'Mirai',
#  'Armine',
#  'Cicely',
#  'Tianah',
#  'Miquela',
#  'Arna',
#  'Miqueas',
#  'Sadiee',
#  'Arnel',
#  'Livvy',
#  'Minnah',
#  'Jannessa',
#  'Minha',
#  'Chynna',
#  'Jannell',
#  'Sadiyah',
#  'Lizbett',
#  'Chuna',
#  'Lochlyn',
#  'Artis',
#  'Christon',
#  'Sahori',
#  'Aryelle',
#  'Aryia',
#  'Chriss',
#  'Teshawn',
#  'Arynn',
#  'Aryona',
#  'Janeah',
#  'Londin',
#  'Terryn',
#  'Jandiel',
#  'Miklo',
#  'Chrisangel',
#  'Saifullah',
#  'Mikiya',
#  'Lorali',
#  'Mikhaela',
#  'Sahmir',
#  'Mileigh',
#  'Aryav',
#  'Christabelle',
#  'Thayer',
#  'Artyom',
#  'Arul',
#  'Safi',
#  'Thanya',
#  'Thanh',
#  'Christo',
#  'Safiatou',
#  'Armida',
#  'Safina',
#  'Sagan',
# ...

# %% [markdown]
# ### Step 11. What is the median name occurrence?

# %%
median_occurrence = baby_names['Frequency'].median()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Frequency'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# ### Step 12. What is the standard deviation of names?

# %% [markdown]
# ### Step 13. Get a summary with the mean, min, max, std and quartiles.
